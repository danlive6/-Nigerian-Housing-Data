# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline

# %%
##Lets import the file and take a look at the first 5 rows and the last 5 rows
df=pd.read_excel(r'C:\Users\Ndako Ahmed Aliyu\Desktop\office\nigeria_houses_data.xlsx')

df.head(5)
# Out:
#    bedrooms  bathrooms  toilets  parking_space                 title     town  \
# 0         6          5        5              4       Detached Duplex  Mabushi
# 1         4          5        5              4     Terraced Duplexes  Katampe
# 2         4          5        5              4       Detached Duplex    Lekki
# 3         4          4        5              6       Detached Duplex     Ajah
# 4         4          4        5              2  Semi Detached Duplex    Lekki
#
#    state      price
# 0  Abuja  450000000
# 1  Abuja  800000000
# 2  Lagos  120000000
# 3  Lagos   40000000
# 4  Lagos   75000000

# %%
df.tail(5)
# Out:
#        bedrooms  bathrooms  toilets  parking_space            title  \
# 24321         2          2        2              4   Block of Flats
# 24322         4          5        5              4   Block of Flats
# 24323         4          5        5              4  Detached Duplex
# 24324         3          4        4              3   Block of Flats
# 24325         4          5        5              4  Detached Duplex
#
#                        town  state     price
# 24321                Kabusa  Abuja  15000000
# 24322           Ado-Odo/Ota   Ogun  25000000
# 24323                 Lekki  Lagos  68000000
# 24324  Victoria Island (VI)  Lagos  78000000
# 24325                 Lekki  Lagos  65000000

# %%
#Now we take a look at the shape to know the total number of rows and columns.
df.shape
# Out:
# (24326, 8)

# %%
#Checking informations about the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24326 entries, 0 to 24325
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       24326 non-null  int64
#  1   bathrooms      24326 non-null  int64
#  2   toilets        24326 non-null  int64
#  3   parking_space  24326 non-null  int64
#  4   title          24326 non-null  object
#  5   town           24326 non-null  object
#  6   state          24326 non-null  object
#  7   price          24326 non-null  int64
# dtypes: int64(5), object(3)
# memory usage: 1.5+ MB

# %%
#checking for number of null values in each column.
df.isnull().sum()
# Out:
# bedrooms         0
# bathrooms        0
# toilets          0
# parking_space    0
# title            0
# town             0
# state            0
# price            0
# dtype: int64

# %%
#Confirming if there exist any null values in the datasets
df.isnull().values.any()
# Out:
# False

# %%
#Showing the data types
df.dtypes
# Out:
# bedrooms          int64
# bathrooms         int64
# toilets           int64
# parking_space     int64
# title            object
# town             object
# state            object
# price             int64
# dtype: object

# %%
#Checking for nan values
df.isna().sum()
# Out:
# bedrooms         0
# bathrooms        0
# toilets          0
# parking_space    0
# title            0
# town             0
# state            0
# price            0
# dtype: int64

# %%
#Checking the Statistical properties of the dataset
df.describe()
# Out:
#            bedrooms     bathrooms       toilets  parking_space         price
# count  24326.000000  24326.000000  24326.000000   24326.000000  2.432600e+04
# mean       4.338814      4.600798      5.176355       4.041725  3.013802e+08
# std        1.138497      1.163161      1.226253       1.399936  1.220403e+10
# min        1.000000      1.000000      1.000000       1.000000  9.000000e+04
# 25%        4.000000      4.000000      5.000000       4.000000  5.200000e+07
# 50%        4.000000      5.000000      5.000000       4.000000  8.500000e+07
# 75%        5.000000      5.000000      6.000000       4.000000  1.600000e+08
# max        9.000000      9.000000      9.000000       9.000000  1.800000e+12

# %%
#Exploratory Data Analysis.
df.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'toilets', 'parking_space', 'title', 'town',
#        'state', 'price'],
#       dtype='object')

# %%
#Lets check the correlations between the columns.
correlations=df.corr()
correlations
# Out:
#                bedrooms  bathrooms   toilets  parking_space     price
# bedrooms       1.000000   0.726557  0.610501       0.158528  0.025734
# bathrooms      0.726557   1.000000  0.719102       0.174129  0.021965
# toilets        0.610501   0.719102  1.000000       0.225345  0.015486
# parking_space  0.158528   0.174129  0.225345       1.000000  0.018370
# price          0.025734   0.021965  0.015486       0.018370  1.000000

# %%
#lets plot a correlation heatmap
plt.figure(figsize=(5,4))
sns.heatmap(correlations,annot=True,cmap='Blues')
plt.title('Correlations Heatmap');

# %%
#Visualizing bedrooms counts
plt.title('Bedrooms-Count')
sns.countplot(df['bedrooms'])
#sns.countplot('bedrooms',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Bedrooms-Count'}, xlabel='bedrooms', ylabel='count'>

# %%
sns.countplot(df['bathrooms'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bathrooms', ylabel='count'>

# %%
fig, ax = plt.subplots()
ax.hist(df['bedrooms'], bins=8, linewidth=0.5, edgecolor="white");

# %%
fg,ax=plt.subplots(figsize=(11,9))
df.hist(ax=ax)
plt.show()
# Out:
# C:\Users\NDAKOA~1\AppData\Local\Temp/ipykernel_6352/3380377635.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df.hist(ax=ax)

# %%
#Showing number of houses in different states
plt.figure(figsize=(18,5))
ax=sns.countplot(x='state', data=df)
for p in ax.patches:
   ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

# %%
state_total=df['state'].value_counts()
state_total

sns.countplot(state_total)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='state', ylabel='count'>

# %%
#Showing regression plot of bathroom and bedrooms correlation.
sns.regplot(df['bathrooms'],df['bedrooms'],marker='+')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bathrooms', ylabel='bedrooms'>

# %%
sns.pairplot(df,hue='bedrooms');

# %%
sns.pairplot(df, diag_kind="kde")

# %%
avg_price = df.groupby(['state'],as_index=False)['price'].agg(np.mean)
av_s=avg_price.rank(ascending=False)

# %%
sns.histplot(df,x='price')

# %%
total_sum_rooms=df.groupby(['bedrooms'],as_index=False)['price'].sum()
total_sum_rooms
# Out:
#    bedrooms          price
# 0         1    92589092259
# 1         2    36321999330
# 2         3   250377725872
# 3         4  1494487536157
# 4         5  2464590907683
# 5         6   547041640000
# 6         7  1968111849999
# 7         8    70092000000
# 8         9   407762200000

# %%
sns.histplot(data=total_sum_rooms)
# Out:
# <AxesSubplot:ylabel='Count'>
